# %% [markdown]
# > # **`Programação de Computadores`**
# > ### **Ciência da Computação - 1º semestre**
# ---
# ---

# %% [markdown]
# > # **Estrutura Lógica Sequencial**
# ---
# ---

# %% [markdown]
# > ## **Variável**: armazena dados (memória do computador).
#
# - ### Nomes (identificadores) para variáveis:
#     - ### Início com `letra` (maiúscula ou minúscula) ou `_`, seguido ou não de `letras`, `dígitos` ou `_`.
#     - ### Exemplos:
#         - ### `a`, `A`, `a123`, `area`, `nome_cliente`, `_contador`, `EnderecoCliente` ...

# %% [markdown]
# > ## **Algoritmo**: sequência finita de passos que soluciona um determinado problema.
#
# - ### Mais informações sobre algoritmos, consulte o livro: Fundamentos da Programação de Computadores (Ascêncio, Ana; Campos, Edilene).

# %% [markdown]
# > ### **Exemplo**: cálculo da área de um retângulo.
#
# - #### area = lado1 . lado2
#
#
#     Algoritmo Area_Retangulo
#     Declare area, lado1, lado2: numérico
#     início
#         leia lado1, lado2
#         area = lado1 * lado2
#         escreva area
#     fim

# %%
# programa para calcular a área de um retângulo

txt = input('Lado 1 (m): ')
lado1 = float(txt)

# %%
# programa para calcular a área de um retângulo

lado1 = float(input('Lado 1 (m): '))
lado2 = float(input('\nLado 2 (m): '))
area = lado1 * lado2
print('\nÁrea do retângulo =', area, 'm²')

# %%
# programa para calcular a área de um retângulo

lado1 = float(input('Lado 1 (m): '))
lado2 = float(input('\nLado 2 (m): '))
area = lado1 * lado2
print(f'\nÁrea do retângulo = {lado1:.3f} x {lado2:.3f} = {area:.3f} m²')
# Out:
# Lado 1 (m): 1.1235
#
# Lado 2 (m): 2.1512
#
# Área do retângulo = 1.123 x 2.151 = 2.417 m²

# %% [markdown]
# > ## **Operadores matemáticos:**
# ---
#
# - ## `+` : soma.
# - ## `-` : subtração.
# - ## `*` : multiplicação (produto).
# - ## `/` : divisão.
# - ## `**` : potência.
# - ## `//` : quociente da divisão entre 2 números.
# - ## `%` : resto da divisão entre 2 números.

# %%
# Exemplo de cálculos com os operadores matemáticos

print('Soma =', 5 + 3)
print('Subtração =', 10 - 8)
print('Multiplicação =', 6 * 7)
print('Divisão =', 9 / 2)
print('Potência =', 2 ** 10)
print('Quociente =', 5 // 2)
print('Resto =', 5 % 2)
# Out:
# Soma = 8
# Subtração = 2
# Multiplicação = 42
# Divisão = 4.5
# Potência = 1024
# Quociente = 2
# Resto = 1

# %% [markdown]
# > ## **Exercícios:**
# ---
# ---

# %% [markdown]
# > ### `1.` Crie um programa para ler `3 notas` (0 a 10) e, após a leitura, calcular e mostrar a média aritmética das notas.

# %%
# Média aritmética de três notas

Nota1 = float(input('Nota 1 (0 a 10): '))
Nota2 = float(input('\nNota 2 (0 a 10): '))
Nota3 = float(input('\nNota 3 (0 a 10): '))
media = (Nota1 + Nota2 + Nota3) / 3
print(f'\nMédia das Notas = {Nota1} + {Nota2} + {Nota3} / {3} = {media:.1f} ')
# Out:
# Nota 1 (0 a 10): 10
#
# Nota 2 (0 a 10): 10
#
# Nota 3 (0 a 10): 10
#
# Média das Notas = 10.0 + 10.0 + 10.0 / 3 = 10.0

# %%
#Correção

n1 = float(input('Nota 1 (0 a 10): '))
n2 = float(input('\nNota 2 (0 a 10): '))
n3 = float(input('\nNota 3 (0 a 10): '))
ma = (n1 + n2 + n3) / 3
print(f'\nMédia aritmética = {ma:.1f}')
# Out:
# Nota 1 (0 a 10): 10
#
# Nota 2 (0 a 10): 10
#
# Nota 3 (0 a 10): 10
#
# Média aritmética = 10.0

# %% [markdown]
# > ### `2.` Crie um programa para ler o `raio` (m) de um círculo e, após a leitura, calcular e mostrar:
# - ### comp = 2 . PI . raio
# - ### area = PI . raio²
#
# ### **OBS.**: PI = 3.1415

# %%
r = float(input('Raio (m): '))
comp = 2 * 3.1415 * r
area = 3.1415 * r ** 2
print(f'\nComprimento = {comp:.1f} m')
print(f'\nÁrea = {area:.1f} m²')
# Out:
# Raio (m): 4
#
# Comprimento = 25.1 m
#
# Área = 50.3 m²

# %%
# Correção

r = float(input('Raio do círculo (m): '))
c = 2 * 3.1415 * r
a = 3.1415 * r ** 2
print(f'\nComprimento do círculo = {c:.4f} m')
print(f'\nÁrea do círculo = {a:.4f} m²')
# Out:
# Raio do círculo (m): 1
#
# Comprimento do círculo = 6.2830 m
#
# Área do círculo = 3.1415 m²

# %% [markdown]
# > ### `Outra forma`: valor de PI do módulo (biblioteca) `math`.

# %%
# import math : importa todas as funções e constantes do módulo math
from math import pi # importa apenas o pi

r = float(input('Raio do círculo (m): '))
c = 2 * pi * r
a = pi * r ** 2
print(f'\nComprimento do círculo = {c:.4f} m')
print(f'\nÁrea do círculo = {a:.4f} m²')
# Out:
# Raio do círculo (m): 2.5
#
# Comprimento do círculo = 15.7080 m
#
# Área do círculo = 19.6350 m²

# %% [markdown]
# > ### `3.` Crie um programa para ler o `preço` de um produto e, após a leitura, calcular e mostrar o valor do produto após um desconto de 7% e o valor do produto após um aumento de 5,5%.

# %%
p = float(input('Preço do Produto (R$): '))
d = p * (1-0.07)
a = p * (1+0.055)
print(f'\nDesconto de 7% = R$ {d:.2f}')
print(f'\nAumento de 5,5% = R$ {a:.2f}')
# Out:
# Preço do Produto (R$): 100
#
# Desconto de 7% = R$ 93.00
#
# Aumento de 5,5% = R$ 105.50

# %%
# Correção

p = float(input('Preço do produto: R$ '))
pd = p - 7 / 100 * p # o 7 pode ser trocado por uma váriavel, para que o usuário possa inserir o valor de desconto
pa = p + 5.5 / 100 * p
print(f'\nPreço com desconto de 7% = R$ {pd:.2f}')
print(f'\nPreço com aumento de 5,5% = R$ {pa:.2f}')
# Out:
# Preço do produto: R$ 100
#
# Preço com desconto de 7% = R$ 93.00
#
# Preço com aumento de 5,5% = R$ 105.50

# %% [markdown]
# > ### `4.` Crie um programa para calcular e mostrar a média ponderada entre 2 notas. As `notas` e seus respectivos `pesos` devem ser fornecidos pelo usuário no início do programa.
# ### Fórmula:
# ### $mp = {n1.p1 + n2.p2 \over p1+p2}$

# %%
n1 = float(input('Nota 1 (0 a 10): '))
p1 = float(input('Peso 1: '))
n2 = float(input('Nota 2 (0 a 10): '))
p2 = float(input('Peso 2: '))
mp = ((n1 * p1) + (n2 * p2)) / (p1 + p2)
print(f'\nMédia Ponderada = {mp:}')
# Out:
# Nota 1 (0 a 10): 5
# Peso 1: 5
# Nota 2 (0 a 10): 5
# Peso 2: 5
#
# Média Ponderada = 5.0

# %%
# Correção

n1 = float(input('Nota 1 (0 a 10): '))
p1 = int(input('Peso 1: '))              # int - apenas números inteiros
n2 = float(input('\nNota 2 (0 a 10): '))
p2 = int(input('Peso 2: '))
mp = (n1 * p1 + n2 * p2) / (p1 + p2)
print(f'\nMédia ponderada = {mp:.1f}')
# Out:
# Nota 1 (0 a 10): 5
# Peso 1: 3
#
# Nota 2 (0 a 10): 7
# Peso 2: 2
#
# Média ponderada = 5.8

# %% [markdown]
# > ### `5.` Uma empresa paga aos seus funcionários um salário fixo mais uma comissão de 7,5% sobre as vendas realizadas por cada funcionário. Sabendo disso, crie um programa para ler o `salário fixo` e o `valor das vendas` de um funcionário e, após as leituras, calcular e mostrar a comissão sobre as vendas e o salário final desse funcionário.

# %%
s = float(input('Salário Fixo (R$): '))
v = float(input('Valor das Vendas (R$): '))
c = v * 0.075
f = s + c
print(f'\nComissão sobre as vendas = R$ {c:.2f}')
print(f'\nSalário Final = R$ {f:.2f}')
# Out:
# Salário Fixo (R$): 5000
# Valor das Vendas (R$): 100000
#
# Comissão sobre as vendas = R$ 7500.00
#
# Salário Final = R$ 12500.00

# %%
# Correção

fixo = float(input('Salário fixo: R$ '))
vendas = float(input('\nTotal de vendas: R$ '))
com = 7.5 / 100 * vendas
final = fixo + com
print(f'\nComissão sobre as vendas = R$ {com:.2f}')
print(f'\nSalário final = R$ {fixo:.2f} + R$ {com:.2f} = R$ {final:.2f}')
# Out:
# Salário fixo: R$ 5000
#
# Total de vendas: R$ 100000
#
# Comissão sobre as vendas = R$ 7500.00
#
# Salário final = R$ 5000.00 + R$ 7500.00 = R$ 12500.00

# %% [markdown]
# > ### `6.` Crie um programa para ler os valores dos `catetos` de um triângulo retângulo e, após a leitura, calcular e mostrar o valor da hipotenusa.
# ### `Obs.`: use Pitágoras para calcular.
# ### $h = \sqrt{ca^2 + cb^2}$

# %%
from math import sqrt

ca = float(input('Cateto A: '))
cb = float(input('Cateto B: '))
h = sqrt((ca**2) + (cb**2))
print(f'\nValor da hipotenusa = {h}')
# Out:
# Cateto A: 3
# Cateto B: 4
#
# Valor da hipotenusa = 5.0

# %%
# Correção

from math import sqrt # sqrt é a função que calcula a raiz quadrada

ca = float(input('Cateto A: '))
cb = float(input('\nCateto B: '))
h = sqrt(ca ** 2 + cb ** 2)
print(f'\nHipotenusa = {h:.3f}')
# Out:
# Cateto A: 3
#
# Cateto B: 4
#
# Hipotenusa = 5.000

# %%
# Outra forma

import math

ca = float(input('Cateto A: '))
cb = float(input('\nCateto B: '))
h = math.sqrt(ca ** 2 + cb ** 2)
print(f'\nHipotenusa = {h:.3f}')
# Out:
# Cateto A: 3
#
# Cateto B: 4
#
# Hipotenusa = 5.000

# %%
# Outra forma

ca = float(input('Cateto A: '))
cb = float(input('\nCateto B: '))
h = (ca ** 2 + cb ** 2) ** 0.5 # ou (1/2)
print(f'\nHipotenusa = {h:.3f}')
# Out:
# Cateto A: 3
#
# Cateto B: 4
#
# Hipotenusa = 5.000

# %% [markdown]
# > ### `7.` Uma escada está apoiada no chão formando um ângulo `a` e há uma distância `d` da parede. A parede forma um ângulo de 90º com o chão. Sabendo disso, crie um programa para ler os valores de `a` (graus) e `d` (metros), calcule e mostre o comprimento da escada (`c`).
#
#     |\
#     | \
#     |  \
#     |   \                      d
#     |    \ c         cos a = -----  ->  c = d / cos a
#     |     \                    c
#     |      \
#     |_      \
#     |.|    a \
#     -----------
#          d

# %%
from math import cos, radians

a = float(input('Ângulo (graus): '))
d = float(input('\nDistância (m): '))
c = d / cos(radians(a))
print(f'\nComprimento da escada = {c:.1f} m')
# Out:
# Ângulo (graus): 60
#
# Distância (m): 2
#
# Comprimento da escada = 4.0 m

# %%
# Outra forma

from math import cos

a = float(input('Ângulo (graus): '))
d = float(input('\nDistância (m): '))
c = d / cos(a * 3.1415 / 180)
print(f'\nComprimento = {c:.1f} m')
# Out:
# Ângulo (graus): 60
#
# Distância (m): 2
#
# Comprimento = 4.0 m

# %% [markdown]
# > ### `8.` Crie um programa para ler uma certa quantidade de `dias`, `horas`, `minutos` e `segundos` (o usuário fornece). Após as leituras, calcular e mostrar a qtde total de segundos contidos nesses valores.

# %%
d = int(input('Dias: '))
h = int(input('\nHoras: '))
m = int(input('\nMinutos: '))
s = int(input('\nSegundos: '))
t = (((d*24)*60)*60) + ((h*60)*60) + (m*60) + s # ou "t = s + m * 60 + h * 60 * 60 + d * 24 * 60 * 60"
print(f'\nTotal de segundos = {t}')
# Out:
# Dias: 1
#
# Horas: 1
#
# Minutos: 1
#
# Segundos: 1
#
# Total de segundos = 90061

# %% [markdown]
# > ### `9.` Crie um programa para ler o `tamanho` de um arquivo em GBytes e a `velocidade` de download de uma rede em Mbits por segundo. Após as leituras, calcular e mostrar o tempo gasto (minutos e segundos) para transferir o arquivo pela rede.
# - ### 1 Byte = 8 bits
# - ### 1 GByte = 1024 MBytes
# ### **Testes para validação do cálculo:**
# - ### `Tamanho`: 1 GB ; `Velocidade`: 300 Mb/s ; `Resultado`: 0 min e 27 seg
# - ### `Tamanho`: 30 GB ; `Velocidade`: 100 Mb/s ; `Resultado`: 40 min e 57 seg

# %%
t = int(input('Tamanho do Arquivo (GBytes): '))
v = int(input('\nVelocidade de Download (Mbits): '))
b = (((t*1024)*1024)*1024)*8
m = b/1000000
s = m/v
min = s/60
print(f'\nFTP (s) = {s:.1f} segundos ')
print(f'\nFTP (min) = {min:.1f} minutos ')
# Out:
# Tamanho do Arquivo (GBytes): 30
#
# Velocidade de Download (Mbits): 100
#
# FTP (s) = 2577.0 segundos
#
# FTP (min) = 42.9 minutos

# %%
# Correção

tam = int(input('Tamanho do arquivo (GByte): '))
vel = int(input('\nVelocidade da rede (Mbit/s): '))
tam_mb = tam * 1024 * 8 # converte o tamanho em Mbit
ts = tam_mb // vel # tempo em segundos (apenas o valor inteiro para descartar os décimos de seg)
tm = ts // 60 # calcula os minutos
ts %= 60 # calcula os segundos que restaram (ts = ts % 60)
print(f'\nTempo gasto de download = {tm} min e {ts} seg')
# Out:
# Tamanho do arquivo (GByte): 30
#
# Velocidade da rede (Mbit/s): 100
#
# Tempo gasto de download = 40 min e 57 seg

# %% [markdown]
# > ### `10.` Crie um programa para ler uma qtde qualquer de `segundos` e converter para **dias**, **horas**, **minutos** e **segundos** restantes.

# %%
s = int(input('Quantidade de segundos: '))
m = s // 60
s %= 60
h = m // 60
m %= 60
d = h // 24
h %= 24
print(f'\n {d} dias, {h} horas, {m} minutos e {s} segundos')
# Out:
# Quantidade de segundos: 90061
#
#  1 dias, 1 horas, 1 minutos e 1 segundos

# %% [markdown]
# ### **Avaliação A2**

# %%
import math

r = float(input('Valor do Raio: '))
d = float(input('\nValor da Distância: '))

a = 2 * math.pi * r ** 2 + 10
v = math.sqrt(5 / (d * r) + a)
              
print(f'\nValor de A: {a:.1f}')
print(f'\nValor de V: {v:.1f}')
# Out:
# Valor do Raio: 10
#
# Valor da Distância: 10
#
# Valor de A: 638.3
#
# Valor de V: 25.3

# %%
import math

a = float(input('Área da construção (em m²): '))

c = a / 3
ct = math.ceil(c)
l = ct / 18
t = math.ceil(l)
p = t * 120

print(f'\nQuantidade de latas de tinta: {t}')
print(f'\nPreço total gasto: R$ {p:.2f}')
# Out:
# Área da construção (em m²): 200
#
# Quantidade de latas de tinta: 4
#
# Preço total gasto: R$ 480.00

# %% [markdown]
# **Correção**

# %%
# Questão 1

from math import sqrt

raio = float(input('Raio: '))
dist = float(input('Distância: '))

a = 2 * 3.1415 * raio ** 2 + 10
v = sqrt(5 / (dist * raio) + a)

print(f'A = {a}\nV = {v}')
# Out:
# Raio: 10
# Distância: 10
# A = 638.3000000000001
# V = 25.265589247037166

# %%
# Questão 2
from math import ceil

area = float(input('Área: '))
qlatas = ceil(area / 3 / 18)
custo = qlatas * 120
print(f'Qtde de latas = {qlatas}\nCusto = R$ {custo:.2f}')
# Out:
# Área: 360
# Qtde de latas = 7
# Custo = R$ 840.00

# %% [markdown]
# > # **Estrutura Lógica Condicional**
# ---
# ---

# %% [markdown]
# > ## **Algoritmo** (Livro: Fundamentos da Programação de Computadores):
# ---
#
#     se ? então     SIMPLES        ? : condição
#     início
#         ...   VERDADEIRO
#     fim
#
#     se ? então     COMPOSTO       ? : condição
#     início
#         ...   VERDADEIRO
#     fim
#     senão
#     início
#         ...   FALSO
#     fim

# %% [markdown]
#  > ## **Linguagem `Python`:** o deslocamento para direita (Tab) inicia um bloco de comandos e o retorno para a coluna à esquerda finaliza o bloco.
#  ---
#
#     if ?:       >> Comando condicional SIMPLES
#         ...
#         ...
#
#     if ?:       >> Comando condicional COMPOSTO
#         ...
#         ...
#     else:
#         ...
#         ...
#
#
# > ### `?` : condição (V ou F).

# %% [markdown]
# > ## **`Condição` (`?`):**
# ---
# - ## Expressão que resulta sempre em **V** ou **F** (True ou False).

# %% [markdown]
# > ## **Operadores relacionais:**
# ---
#
# - ## Algoritmo: < <= > >= = <> (diferente).
# - ## Python: `<` `<=` `>` `>=` `==` `!=`

# %% [markdown]
# > ### **Exemplos:**
#
# ### `a == 0`
# ### `nota >= 6`
# ### `salario != 5000.0`
# ### `x < 0`
# ### `sqrt(w) >= 10 - y`

# %% [markdown]
# > ## **Operadores Lógicos:**
# ---
#
# - ### Condições compostas: duas ou mais condições.
#
# - ## Algoritmo: e ou não (negação)
# - ## Python: `and` `or` `not`

# %% [markdown]
# > ## Tabela Verdade - `and`
# ---
# Condição 1 | Condição 2 | `AND`
# - | - | -
# F | F | F
# F | V | F
# V | F | F
# V | V | V

# %% [markdown]
# > ## Tabela Verdade - `or`
# ---
# Condição 1 | Condição 2 | `OR`
# - | - | -
# F | F | F
# F | V | V
# V | F | V
# V | V | V

# %% [markdown]
# > ## Tabela Verdade - `not`
# ---
# Condição | `NOT`
# - | -
# F | V
# V | F

# %% [markdown]
# > ### **Exemplos:**
#
# ### `a >= 0 and a <= 10`
# ### `a < 0 or a > 10`
# ### `not (a >= 0 and a <= 10)`
# ### `not (a < 0 and (x != 2 or d == -1) and nota != 10)`

# %% [markdown]
# > ## **Prioridade (ou precedência) de Operadores:**
#
# [https://www.inf.pucrs.br/flash/algfis/aulas/selecao/build/selecao/PrecedenceofOperators.html](https://www.inf.pucrs.br/flash/algfis/aulas/selecao/build/selecao/PrecedenceofOperators.html)

# %% [markdown]
# > ## **Exercícios:**
# ---
# ---

# %% [markdown]
# > ### `1.` Crie um programa para ler `2 notas`, calcular e mostrar a média aritmética e informar se o aluno foi aprovado ou reprovado (média mínima = 6.0). Mostrar também uma mensagem de 'Parabéns!', caso ele tenha uma média igual a 10.

# %%
n1 = float(input('Nota 1 (0 a 10): '))
n2 = float(input('\nNota 2 (0 a 10): '))
ma = (n1 + n2) / 2
print(f'\nMédia final = {ma:.1f}')

if ma >= 6:
    print('\nAPROVADO!!!', end='') # end='' impede que o print vá para a próxima linha
    if ma == 10:
        print('  PARABÉNS!!!')
else:
    print('\nREPROVADO!!!')
# Out:
# Nota 1 (0 a 10): 7
#
# Nota 2 (0 a 10): 8
#
# Média final = 7.5
#
# APROVADO!!!

# %% [markdown]
# > ### `2.` Criar um programa para ler `3 valores` inteiros e, após as leituras, mostrar o menor e o maior valor entre os 3.

# %%
a = int(input('A: '))
b = int(input('\nB: '))
c = int(input('\nC: '))

if a < b and a < c:
    me = a
elif b < c:
    me = b
else:
    me = c

if a > b and a > c:
    ma = a
elif b > c:
    ma = b
else:
    ma = c
    
print(f'\nMenor = {me}')
print(f'\nMaior = {ma}')
# Out:
# A: 5
#
# B: 2
#
# C: 8
#
# Menor = 2
#
# Maior = 8

# %% [markdown]
# > ### `3.` Criar um programa para ler `3 valores` inteiros e, após as leituras, mostrar o menor e o maior valor digitado pelo usuário, seguindo as regras:
#
# - ### Usar apenas `if` (NÃO pode usar `else`, nem `elif`).
# - ### NÃO pode usar o operador lógico `and`.

# %%
a = int(input('Valor de A: '))
b = int(input('\nValor de B: '))
c = int(input('\nValor de C: '))

me = a # primeiro é o menor
if b < me: # verifica se o segundo é o menor
    me = b
if c < me: # verifica se o terceiro é o menor
    me = c

ma = a # primeiro é o maior
if b > ma: # verifica se o segundo é o maior
    ma = b
if c > ma: # verifica se o terceiro é o maior
    ma = c

print(f'\nMenor = {me}\n\nMaior = {ma}')
# Out:
# Valor de A: 3
#
# Valor de B: 2
#
# Valor de C: 6
#
# Menor = 2
#
# Maior = 6

# %% [markdown]
# > ### `4.` Criar um programa para ler um número inteiro qualquer e, após a leitura, mostrar se o número é PAR ou ÍMPAR.

# %%
num = int(input('Número inteiro: '))

if num % 2 == 0: # verificar se num é múltiplo de 2 (resto da divisão por 2 igual a zero)
    print(f'\n{num} é PAR!!')
else:
    print(f'\n{num} é ÍMPAR!!')
# Out:
# Número inteiro: 11
#
# 11 é ÍMPAR!!

# %% [markdown]
# > ### `Observação`: o operador `%` pode ser usado para verificar se um número é múltiplo de qualquer outro número.

# %%
x = int(input('X: '))
y = int(input('\nY: '))

if x % y == 0:
    print(f'\n{x} é múltiplo de {y}')
else:
    print(f'\n{x} NÃO é múltiplo de {y}')
# Out:
# X: 3425
#
# Y: 30
#
# 3425 NÃO é múltiplo de 30

# %% [markdown]
# > ### `5.` Criar um programa para ler `2 valores` reais (float) e, caso o primeiro valor seja maior que o segundo, trocar os valores das duas variáveis e mostrar seus resultados.

# %%
p = float(input('Primeiro valor: '))
s = float(input('\nSegundo valor: '))

if p > s:
    aux = p
    p = s
    s = aux
    print('\nTrocou...')

print(f'\nPrimeiro = {p}\n\nSegundo = {s}')
# Out:
# Primeiro valor: 5
#
# Segundo valor: 1
#
# Trocou...
#
# Primeiro = 1.0
#
# Segundo = 5.0

# %% [markdown]
# > ### `Outra forma`: "método Python" de trocar.

# %%
p = float(input('Primeiro valor: '))
s = float(input('\nSegundo valor: '))

if p > s:
    p, s = s, p
    print('\nTrocou...')

print(f'\nPrimeiro: {p}\n\nSegundo = {s}')
# Out:
# Primeiro valor: 20
#
# Segundo valor: 10
#
# Trocou...
#
# Primeiro: 10.0
#
# Segundo = 20.0

# %% [markdown]
# > ### `6.` Criar um programa para ler `5 valores` inteiros e, após as leituras, calcular e mostrar a qtde de valores negativos entre os 5 valores.
# + ### `Dica`: use um contador.

# %%
v1 = int(input('Valor 1: '))
v2 = int(input('Valor 2: '))
v3 = int(input('Valor 3: '))
v4 = int(input('Valor 4: '))
v5 = int(input('Valor 5: '))

qn = 0 # qtde de negativos (contador)

if v1 < 0:
    qn += 1
if v2 < 0:
    qn += 1
if v3 < 0:
    qn += 1
if v4 < 0:
    qn += 1
if v5 < 0:
    qn += 1

print(f'\nQtde de negativos = {qn}')

# %% [markdown]
# > ### `7.` Criar um programa para ler a `distância` (em Km) e o `consumo` de combustível (em litros) de um carro ao percorrer um trajeto qualquer. Após as leituras, calcular e mostrar o consumo médio (em Km/litro) do carro e um aviso seguinto a tabela abaixo:
# Consumo Médio (Km/litro)|Aviso!
# -|-
# Abaixo de 8|Venda o carro!!
# Entre 8 e 14|Econômico!!
# Acima de 14|Super econômico!!
#
# <br>

# %%
di = float(input('Distância (Km): '))
cc = float(input('\nConsumo de combustível (litros): '))
cm = di / cc
print(f'\nConsumo médio do veículo = {cm:.1f} Km/l')

print('\nAVISO: ', end='')
if cm < 8:
    print('venda o carro!!')
elif cm <= 14:
    print('econômico!!')
else:
    print('super econômico!!')
# Out:
# Distância (Km): 100
#
# Consumo de combustível (litros): 4
#
# Consumo médio do veículo = 25.0 Km/l
#
# AVISO: super econômico!!

# %% [markdown]
# > ### `8.` Criar um programa para ler a `idade` (em anos) de um nadador e, após a leitura, mostrar sua categoria seguindo a tabela abaixo:
# Categoria|Idade (em anos)
# -|-
# NA|Abaixo de 5
# Infantil A|5 a 7
# Infantil B|8 a 10
# Juvenil A|11 a 14
# Juvenil B|15 a 18
# Senior|Acima de 18
#
# <br>

# %%
id = int(input('Idade em anos: '))

if id < 5:
    cat = 'NA'
elif id <= 7:
    cat = 'Infantil A'
elif id <= 10:
    cat = 'Infantil B'
elif id <= 14:
    cat = 'Juvenil A'
elif id <= 18:
    cat = 'Juvenil B'
else:
    cat = 'Senior'

print(f'\nCategoria: {cat}')
# Out:
# Idade em anos: 15
#
# Categoria: Juvenil B

# %% [markdown]
# > ### `9.` Criar um programa para ler `3 valores` inteiros e, após as leituras, mostrá-los em ordem crescente.

# %%
a = int(input('A: '))
b = int(input('\nB: '))
c = int(input('\nC: '))

print('\nOrdem crescente: ', end='')
if a < b and b < c:
    print(f'{a}, {b}, {c}')
elif a < c and c < b:
    print(f'{a}, {c}, {b}')
elif b < a and a < c:
    print(f'{b}, {a}, {c}')
elif b < c and c < a:
    print(f'{b}, {c}, {a}')
elif c < a and a < b:
    print(f'{c}, {a}, {b}')
else:
    print(f'{c}, {b}, {a}')

# %% [markdown]
# > ### `Outra forma`: fazer o mesmo que foi pedido no exercício `9` usando apenas `3 if's` (sem else ou elif).

# %%
a = int(input('A: '))
b = int(input('\nB: '))
c = int(input('\nC: '))

if a > b:
    a, b = b, a

if b > c:
    b, c = c, b

if a > b:
    a, b = b, a

print(f'\nOrdem crescente: {a}, {b}, {c}')
# Out:
# A: 3
#
# B: 2
#
# C: 1
#
# Ordem crescente: 1, 2, 3

# %%
# Método utilizando listas

a = int(input('A: '))
b = int(input('\nB: '))
c = int(input('\nC: '))

lista = [a, b, c]
lista.sort()

print(lista)
# Out:
# A: 3
#
# B: 2
#
# C: 1
# [1, 2, 3]

# %% [markdown]
# > ### `10.` Criar um programa para ler `3 valores` reais (float) e, após as leituras, verificar se os valores podem ou não formar um triângulo. Caso formem um triângulo, mostrar qual o seu tipo.
# - ### `Regra para formar um triângulo`: cada um dos lados deve ser menor que a soma dos outros dois lados.
# - ### Tipos: **`equilátero`** (3 lados iguais), **`isósceles`** (apenas 2 lados iguais) ou **`escaleno`** (3 lados diferentes).

# %%
a = float(input('Lado A: '))
b = float(input('\nLado B: '))
c = float(input('\nLado C: '))

if a < b + c and b < a + c and c < a + b:
    if a == b and b == c:               # a == b == c
        print('\nTriângulo Equilátero!')
    elif a == b or a == c or b == c:    # elif a != b and a != c and b != c:
        print('\nTriângulo Isósceles!') # print('\nTriângulo Escaleno!')
    else:
        print('\nTriângulo Escaleno!')
else:
    print('\nNão formam um triângulo!')

# %% [markdown]
# > ### `11.` Criar um programa para ler a `idade` e o `tempo` de serviço de um trabalhador (em anos) e, após as leituras, mostrar uma mensagem informando se ele pode ou não se aposentar. As condições para aposentadoria são:
# + ### Ter pelo menos 65 anos de idade.
# + ### Ou ter trabalhado pelo menos 30 anos.
# + ### Ou ter pelo menos 60 anos de idade e ter trabalhado pelo menos 25 anos.

# %%
i = int(input('Idade: '))
t = int(input('Tempo de serviço: '))

if i >= 65 or t >= 30 or (i >= 60 and t >= 25):
    print('Pode aposentar')
else:
    print('Não pode aposentar')
# Out:
# Idade: 64
# Tempo de serviço: 25
# Pode aposentar

# %% [markdown]
# > ### `12.` Criar um programa para ler a `altura` (m) e o `peso` (Kg) de uma pessoa e, após as leituras, mostrar a classificação dessa pessoa através da tabela abaixo:
# Altura||Peso||
# :-:|:-:|:-:|:-:
# |Até 60|Entre 60 e 90 (inclusive)|Acima de 90
# Abaixo de 1,2|A|D|G
# De 1,2 a 1,7|B|E|H
# Acima de 1,7|C|F|I
#
# <br>

# %%
a = float(input('Altura (m): '))
p = float(input('Peso (Kg): '))

if p <= 60:
    if a < 1.2:
        print('A')
    elif a >= 1.2 and a <= 1.7:
        print('B')
    else: # a > 1.7
        print('C')

elif p > 60 and p <= 90:
    if a < 1.2:
        print('D')
    elif a >= 1.2 and a <= 1.7:
        print('E')
    else: # a > 1.7
        print('F')

else: # p > 90
    if a < 1.2:
        print('G')
    elif a >= 1.2 and a <= 1.7:
        print('H')
    else: # a > 1.7
        print('I')
# Out:
# Altura (m): 1.9
# Peso (Kg): 75
# F

# %%
alt = float(input('Altura (m): '))
peso = float(input('\nPeso (Kg): '))

if alt < 1.2:
    if peso <= 60:
        cla = 'A'
    elif peso <= 90:
        cla = 'D'
    else:
        cla = 'G'
elif alt <= 1.7:
    if peso <= 60:
        cla = 'B'
    elif peso <= 90:
        cla = 'E'
    else:
        cla = 'H'
else:
    if peso <= 60:
        cla = 'C'
    elif peso <= 90:
        cla = 'F'
    else:
        cla = 'I'

print(f'\nClassificação: {cla}')
# Out:
# Altura (m): 1.9
#
# Peso (Kg): 75
#
# Classificação: F

# %% [markdown]
# > ### `13.` Criar um programa para ler `2 valores` reais (float) e, após as leituras, mostrar o menu de opções mostrado abaixo e ler a `escolha` do usuário. Após a escolha, calcular e mostrar o resultado da operação selecionada. Caso a opção escolhida seja inválida, mostrar uma mensagem ao usuário.
# ### Exemplo de execução:
#     Opções:
#     1. Soma dos dois valores.
#     2. Diferença dos dois valores (maior - menor).
#     3. Multiplicação dos dois valores.
#     4. Divisão dos dois valores (1º pelo 2º).
#     Escolha:

# %%
a = float(input('Digite um valor: '))
b = float(input('Digite um valor: '))
print('\nOpções:')
print('\n1. Soma dos dois valores.\n2. Diferença dos dois valores (maior - menor).\n3. Multiplicação dos dois valores.\n4. Divisão dos dois valores (1º pelo 2º).')
e = int(input('\nEscolha: '))

if e == 1:
    print(f'\n{a + b}')

elif e == 2:
    if a > b:
        print(f'\n{a - b}')
    else:
        print(f'\n{b - a}')

elif e == 3:
    print(f'\n{a * b}')

elif e == 4:
    print(f'\n{a / b}')

else:
    print('\nOpção Inválida')
# Out:
# Digite um valor: 10
# Digite um valor: 5
#
# Opções:
#
# 1. Soma dos dois valores.
# 2. Diferença dos dois valores (maior - menor).
# 3. Multiplicação dos dois valores.
# 4. Divisão dos dois valores (1º pelo 2º).
#
# Escolha: 2
#
# 5.0

# %%
from IPython.display import clear_output

v1 = float(input('Valor 1: '))
v2 = float(input('\nValor 2: '))
clear_output(True) # limpa a saída de dados
print('Opções:')
print('1 - Soma dos dois valores.')
print('2 - Diferença dos dois valores (maior - menor).')
print('3 - Multiplicação dos dois valores.')
print('4 - Divisão dos dois valores (1º pelo 2º).')
op = int(input('Escolha: '))

if op == 1:
    soma = v1 + v2
    print(f'\nSoma = {v1} + {v2} = {soma}')
elif op == 2:
    if v1 < v2:
        v1, v2 = v2, v1 # troca o valor de v1 com v2, se v1 for menor que v2
    dif = v1 - v2
    print(f'\nDiferença = {v1} - {v2} = {dif}')
elif op == 3:
    mult = v1 * v2
    print(f'\nMultiplicação = {v1} * {v2} = {mult}')
elif op == 4:
    div = v1 / v2
    print(f'\nDivisão = {v1} / {v2} = {div}')
else:
    print(f'\nOpção inválida!!')
# Out:
# Opções:
# 1 - Soma dos dois valores.
# 2 - Diferença dos dois valores (maior - menor).
# 3 - Multiplicação dos dois valores.
# 4 - Divisão dos dois valores (1º pelo 2º).
# Escolha: 2
#
# Diferença = 9.0 - 6.0 = 3.0

# %% [markdown]
# > ### `Extra`: Comando `switch` (exemplo em linguagem C, pois Python não possui o comando).
# ---
# ---

# %%
switch (op)
{
    case 1:
        printf('\nOpcao 1');
        break;
    case 2:
        printf('\nOpcao 2');
        break;
    default:
        printf('\nOpcao invalida!!');
}

# %% [markdown]
# > ### `14.` Criar um programa para ler uma `data` (dia, mês e ano) e, após a leitura, mostrar uma mensagem informando se a data é válida ou inválida.

# %%
d = int(input('Dia: '))
m = int(input('Mês: '))
a = int(input('Ano: '))

data = True

if a < 1 or m < 1 or m > 12 or d < 1 or d > 31:
    data = False

elif m==4 or m==6 or m==9 or m==11:
    if d > 30:
        data = False

elif m==2:
    if d > 29:
        data = False
    elif not (a % 4 == 0):
        if d > 28:
            data = False
if(data):
    print('Data Válida')
else:
    print('Data Inválida')
# Out:
# Dia: 29
# Mês: 2
# Ano: 2020
# Data Válida

# %%
dia = int(input('Dia: '))
mes = int(input('Mês: '))
ano = int(input('Ano: '))

valida = False
    
# Meses com 31 dias
if( mes==1 or mes==3 or mes==5 or mes==7 or \
    mes==8 or mes==10 or mes==12):
    if(dia<=31):
        valida = True
# Meses com 30 dias
elif( mes==4 or mes==6 or mes==9 or mes==11):
    if(dia<=30):
        valida = True
elif mes==2:
    # Testa se é bissexto
    if (ano%4==0 and ano%100!=0) or (ano%400==0):
        if(dia<=29):
            valida = True
    elif(dia<=28):
            valida = True

if(valida):
    print('Data válida')
else:
    print('Inválida')
# Out:
# Dia: 19
# Mês: 04
# Ano: 2004
# Data válida

# %% [markdown]
# > ### `Extra`: Comando `split`.
# ---
# ---

# %%
'1 2 3'.split()
# Out:
# ['1', '2', '3']

# %%
'1,2,3'.split(',')
# Out:
# ['1', '2', '3']

# %%
h, m = input('Horário (hh:mm): ').split(':')
h, m = int(h), int(m)
print(h, m)
# Out:
# Horário (hh:mm): 19:51
# 19 51

# %% [markdown]
# **Dica:** `if` dentro de `if` = `and`

# %%
d, m, a = input('Data (dd/mm/aaaa): ').split('/')
d, m, a = int(d), int(m), int(a)

val = True # val é a variável que indica se a data é válida ou não (flag)

if a < 1 or m < 1 or m > 12 or d < 1 or d > 31:
    val = False
elif (m == 4 or m == 6 or m == 9 or m == 11) and d > 30:
    val = False
elif m == 2:
    if a % 4 == 0: # ano bissexto (múltiplo de 4)
        if d > 29:
            val = False
    elif d > 28: # ano não bissexto
        val = False

if val:
    print('\nVÁLIDA!!!')
else:
    print('\nINVÁLIDA!!!')
# Out:
# Data (dd/mm/aaaa): 31/12/2022
#
# VÁLIDA!!!

# %%
n1 = float(input('Insira: '))
n2 = float(input('Insira: '))
n3 = float(input('Insira: '))

max = n1
min = n1

if n2 > max:
    max = n2
if n3 > max:
    max = n3

if n2 < min:
    min = n2
if n3 < min:
    min = n3

print(max, min)

# %%
# PROVA

if valor1 >= 0:
    acumulador += valor1
    contador += 1

if valor2 >= 0:
    acumulador += valor2
    contador += 1

if valor3 >= 0:
    acumulador += valor3
    contador += 1

if valor4 >= 0:
    acumulador += valor4
    contador += 1

if contador <= 0:
    print('Não há valores positivos')
else:
    print(acumulador / contador)

# %%
#PROVA
a = float(input('A: '))
b = float(input('B: '))
c = float(input('C: '))
d = float(input('D: '))

qp = sp = 0

if a >= 0:
    sp += a
    qp += 1
    
if b >= 0:
    sp += b
    qp += 1

if c >= 0:
    sp += c
    qp += 1

if d >= 0:
    sp += d
    qp += 1

if qp > 0:
    mp = sp / qp
    print(mp)
else:
    print('Não há positivos!')


#criar 5 variaveis e se mostrar quais valores repetiram, apenas 1 vez

prova da outra turma

a = int(input('A: '))
b = int(input('B: '))
c = int(input('C: '))
d = int(input('D: '))
e = int(input('E: '))

if a == b or a == c or a == d or a == e:
    print(a)
if (b == c or b == d or b == e) and b != a:
    print(b)
if (c == d or c == e) and c != a and c != b:
    print(c)
if d == e and d != a and d != b and d != c and d != e:
    print(d)

# %% [markdown]
# > ### `Exercício 1 da Prova A1.` Receba 3 valores a, b e c (float) e imprima o valor de r.
#
# ![vasco.PNG](data:image/png;base64,...)

# %%
a = float(input(f'\nInsira o valor a: '))
b = float(input(f'Insira o valor b: '))
c = float(input(f'Insira o valor c: '))

s1 = (a - (b ** c)) / (2 + a)

s2 = (c * a)**(1/2) + b

r = (s1 - s2) / (s1 + s2)

print(f'\nO valor de r será {r:.2f}')

# %% [markdown]
# > ### `Exercício 2 da Prova A1.` Receba 3 valores inteiros para o usuário digitar e imprima o valor intermediário (do meio).

# %%
v1 = int(input(f'\nInsira valor 1: '))
v2 = int(input(f'Insira valor 2: '))
v3 = int(input(f'Insira valor 3: '))

if v2 < v1 < v3 or v3 < v1 < v2:  # verificando se v1 é o valor medio
    print(f'\nO valor médio é {v1}.')
elif v1 < v2 < v3 or v3 < v2 < v1:  # verificando se v2 é o valor medio
    print(f'\nO valor médio é {v2}.')
else:  # verificando se v3 é o valor medio
    print(f'\nO valor médio é {v3}.')

# %%
a = int(input('Valor A: '))
b = int(input('Valor B: '))
c = int(input('Valor C: '))

if a > b and a > c:
    if b > c:
        print(b)
    else:
        print(c)

elif b > a and b > c:
    if a > c:
        print(a)
    else:
        print(c)

else:
    if a > b:
        print(a)
    else:
        print(c)
